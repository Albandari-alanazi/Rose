# %% [markdown]
# # Student Mental health

# %% [markdown]
# The source:https://www.kaggle.com/datasets/shariful07/student-mental-health/data

# %% [markdown]
# #  1-Data Cleaning

# %%
# Read data from CSV file
daurl = ('/content/Student Mental health.csv')
# Import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns

ta = pd.read_csv(url)
data
# Out:
#                Timestamp Choose your gender   Age What is your course?  \
# 0         8/7/2020 12:02             Female  18.0          Engineering
# 1         8/7/2020 12:04               Male  21.0    Islamic education
# 2         8/7/2020 12:05               Male  19.0                  BIT
# 3         8/7/2020 12:06             Female  22.0                 Laws
# 4         8/7/2020 12:13               Male  23.0         Mathemathics
# ..                   ...                ...   ...                  ...
# 96   13/07/2020 19:56:49             Female  21.0                  BCS
# 97   13/07/2020 21:21:42               Male  18.0          Engineering
# 98   13/07/2020 21:22:56             Female  19.0             Nursing
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# ...

# %% [markdown]
# Explore Data

# %%
data.head(10)
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
# 3  8/7/2020 12:06             Female  22.0                 Laws
# 4  8/7/2020 12:13               Male  23.0         Mathemathics
# 5  8/7/2020 12:31               Male  19.0          Engineering
# 6  8/7/2020 12:32             Female  23.0     Pendidikan islam
# 7  8/7/2020 12:33             Female  18.0                  BCS
# 8  8/7/2020 12:35             Female  19.0      Human Resources
# 9  8/7/2020 12:39               Male  18.0                Irkhs
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# ...

# %%
data.tail(10)
# Out:
#                Timestamp Choose your gender   Age What is your course?  \
# 91   13/07/2020 14:38:12               Male  18.0                  Koe
# 92   13/07/2020 14:48:05             Female  19.0                  KOE
# 93   13/07/2020 16:15:13             Female  18.0                 BENL
# 94   13/07/2020 17:30:44             Female  24.0                 Fiqh
# 95   13/07/2020 19:08:32             Female  18.0    Islamic Education
# 96   13/07/2020 19:56:49             Female  21.0                  BCS
# 97   13/07/2020 21:21:42               Male  18.0          Engineering
# 98   13/07/2020 21:22:56             Female  19.0             Nursing
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# 91                      Year 2        3.00 - 3.49             No
# ...

# %%
data.shape
# Out:
# (101, 11)

# %%
data.columns
# Out:
# Index(['Timestamp', 'Choose your gender', 'Age', 'What is your course?',
#        'Your current year of Study', 'What is your CGPA?', 'Marital status',
#        'Do you have Depression?', 'Do you have Anxiety?',
#        'Do you have Panic attack?',
#        'Did you seek any specialist for a treatment?'],
#       dtype='object')

# %% [markdown]
#  Check data types

# %%
print(data.dtypes)
# Out:
# Timestamp                                        object
# Choose your gender                               object
# Age                                             float64
# What is your course?                             object
# Your current year of Study                       object
# What is your CGPA?                               object
# Marital status                                   object
# Do you have Depression?                          object
# Do you have Anxiety?                             object
# Do you have Panic attack?                        object
# Did you seek any specialist for a treatment?     object
# dtype: object

# %% [markdown]
# Check for missing values

# %%
print(data.isnull().sum())
# Out:
# Timestamp                                       0
# Choose your gender                              0
# Age                                             1
# What is your course?                            0
# Your current year of Study                      0
# What is your CGPA?                              0
# Marital status                                  0
# Do you have Depression?                         0
# Do you have Anxiety?                            0
# Do you have Panic attack?                       0
# Did you seek any specialist for a treatment?    0
# dtype: int64

# %% [markdown]
# Check for data quality

# %%
print(data.head())
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
# 3  8/7/2020 12:06             Female  22.0                 Laws
# 4  8/7/2020 12:13               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 11 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Timestamp                                     101 non-null    object
#  1   Choose your gender                            101 non-null    object
#  2   Age                                           100 non-null    float64
#  3   What is your course?                          101 non-null    object
#  4   Your current year of Study                    101 non-null    object
#  5   What is your CGPA?                            101 non-null    object
#  6   Marital status                                101 non-null    object
#  7   Do you have Depression?                       101 non-null    object
#  8   Do you have Anxiety?                          101 non-null    object
# ...

# %% [markdown]
#  Basic statistics of the dataset

# %%
data.describe()
# Out:
#              Age
# count  100.00000
# mean    20.53000
# std      2.49628
# min     18.00000
# 25%     18.00000
# 50%     19.00000
# 75%     23.00000
# max     24.00000

# %% [markdown]
# Renaming column head.

# %%
data.rename(columns = {'Choose your gender':'Gender', 'What is your course?':'Course',
                     'Your current year of Study':'Current Year', 'What is your CGPA?':'CGPA',
                    'Do you have Depression?':'Depression', 'Do you have Anxiety?':'Anxiety',
                    'Do you have Panic attack?':'Panic Attack', 'Did you seek any specialist for a treatment?':'Treatment'}, inplace = True)
data['Timestamp'] = pd.to_datetime(data['Timestamp'])
data['Year'] = data['Timestamp']

# %% [markdown]
# #2-Visualization

# %%
data['Gender'].value_counts()
# Out:
# Female    75
# Male      26
# Name: Gender, dtype: int64

# %% [markdown]
# using historgram

# %%
sns.histplot(data['Gender'].sort_values(),kde=True)
plt.title('Female or Male')
# Out:
# Text(0.5, 1.0, 'Female or Male')

# %%
target_gender = 'Female'

# %%
data['Current Year'].value_counts()
# Out:
# year 1    41
# Year 3    19
# Year 2    16
# year 2    10
# year 4     8
# year 3     5
# Year 1     2
# Name: Current Year, dtype: int64

# %%
sns.histplot(data['Current Year'].sort_values(),kde=True)
plt.title('Yearly distribution')
# Out:
# Text(0.5, 1.0, 'Yearly distribution')

# %%
data['Age'].value_counts()
# Out:
# 18.0    32
# 24.0    23
# 19.0    21
# 23.0    13
# 20.0     6
# 21.0     3
# 22.0     2
# Name: Age, dtype: int64

# %% [markdown]
# Boxenplot

# %%
sns.boxplot(data=data,x='Depression',y='Age')
plt.title('Depression by Age')
# Out:
# Text(0.5, 1.0, 'Depression by Age')

# %%
 data['CGPA'].value_counts()
# Out:
# 3.50 - 4.00     47
# 3.00 - 3.49     43
# 2.50 - 2.99      4
# 0 - 1.99         4
# 2.00 - 2.49      2
# 3.50 - 4.00      1
# Name: CGPA, dtype: int64

# %%
sns.boxplot(data=data,x='CGPA',y='Age')
plt.title('CGPA distributione')
# Out:
# Text(0.5, 1.0, 'CGPA distributione')

# %%
 data['Marital status'].value_counts()
# Out:
# No     85
# Yes    16
# Name: Marital status, dtype: int64

# %%
plt.subplot(1,2,2)
sns.countplot(data=data, x= 'Depression')
plt.title("Depression frequency")
# Out:
# Text(0.5, 1.0, 'Depression frequency')

# %%
data['Anxiety'].value_counts()
# Out:
# No     67
# Yes    34
# Name: Anxiety, dtype: int64

# %%
plt.subplot(1,2,2)
sns.countplot(data=data, x= 'Anxiety')
plt.title("Do you have Anxiety?")
# Out:
# Text(0.5, 1.0, 'Do you have Anxiety?')

# %%
data['Panic Attack'].value_counts()
# Out:
# No     68
# Yes    33
# Name: Do you have Panic attack?, dtype: int64

# %%
sns.displot(data['Panic Attack'],color='skyblue',edgecolor='black')
plt.xlabel(' Panic attack')
plt.ylabel('Count')
plt.title('Do you have Panic attack?')
# Out:
# Text(0.5, 1.0, 'Do you have Panic attack?')

# %%
data['Treatment'].value_counts()
# Out:
# No     95
# Yes     6
# Name: Treatment, dtype: int64

# %%
sns.displot(data['Treatment'],color='skyblue',edgecolor='black')
plt.xlabel('Did you seek any specialist for a treatment?')
plt.ylabel('Count')
plt.title('Seek Specialist')
# Out:
# Text(0.5, 1.0, 'Seek Specialist')

# %% [markdown]
# #3-Output

# %%
data
output = data[(data["Depression"]=='Yes') & (data["Anxiety"]=='Yes') & (data["Panic Attack"]=='Yes')].reset_index(drop=True)

output.drop(output.columns[[0, 6, 11]], axis = 1, inplace = True)
print("Students Most Depressed, Anxiety, and Panic Attacks\n")
output
# Out:
# Students Most Depressed, Anxiety, and Panic Attacks
#    Gender   Age          Course Current Year         CGPA Depression Anxiety  \
# 0    Male  19.0             BIT       Year 1  3.00 - 3.49        Yes     Yes
# 1  Female  24.0             ENM       year 4  3.00 - 3.49        Yes     Yes
# 2  Female  18.0  Marine science       year 2  3.50 - 4.00        Yes     Yes
# 3  Female  23.0             BCS       Year 3  3.50 - 4.00        Yes     Yes
# 4  Female  24.0             BIT       Year 3  3.50 - 4.00        Yes     Yes
# 5  Female  19.0             BIT       year 1  3.00 - 3.49        Yes     Yes
# 6  Female  19.0             BIT       year 1  2.50 - 2.99        Yes     Yes
# 7  Female  20.0             koe       year 3  3.00 - 3.49        Yes     Yes
# 8  Female  24.0  Communication        Year 2  3.50 - 4.00        Yes     Yes
# 9  Female  18.0      psychology       year 1  3.50 - 4.00        Yes     Yes
#
#   Panic Attack Treatment
# 0          Yes        No
# ...

# %% [markdown]
# Students Most Depressed, Anxiety, and Panic Attacks
